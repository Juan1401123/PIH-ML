# %%
import pandas as pd
from Datos import Ultimate_df
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Gran parte de los titulos de la base de datos tienen caracteres extranos

# %%
Ultimate_df.sort_values('title')[['title']]
# Out:
#                        title
# 18757  !Women Art Revolution
# 30961    #1 Cheerleader Camp
# 36153                #Horror
# 23501           #chicagoGirl
# 28042    $1,000 on the Black
# ...                      ...
# 19730                    NaN
# 29502                    NaN
# 29503                    NaN
# 35586                    NaN
# 35587                    NaN
#
# [45466 rows x 1 columns]

# %%
plt.figure(figsize= (10,12))
sns.heatmap(Ultimate_df[['title','vote_count','vote_average']].isnull(), cbar=True)
plt.show()

# %% [markdown]
# Como podemos observar no hay valores nulos relevates

# %%
Ultimate_df[['title','vote_count','vote_average']].isnull().sum()
# Out:
# title           6
# vote_count      6
# vote_average    6
# dtype: int64

# %% [markdown]
# Encontramos Valores repetidos por lo tanto hay que redfinir el promedio de rating

# %%
len(Ultimate_df)-len(Ultimate_df['title'].unique())
# Out:
# 3188

# %% [markdown]
# Notamos que la mayor cantidad de puntuaciones se concentran en aproximadamente 1500 peliculas, por lo tanto habra que hacer en el Modelo de recomendacion por similitud una reduccion de la base de datos, a las primeras 1500 con mayor numero de puntuaciones.

# %%
Ultimate_df['vote_count'].hist()
plt.title('Distribucion de numero de puntuaciones por pelicula')
plt.show()

# %% [markdown]
# En conclusion,esto nos da un buen punto de partida para realizar las trasnformaciones pertinentes, con la cual nuestra base de datos este lista para consumir por el modelo de similutud.
